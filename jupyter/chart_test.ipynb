# %%
import numpy as np
# import pandas as pd
# from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %% [markdown]
# ### API Call
#
# https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_DAILY&symbol=BTC&market=CNY&apikey=demo

# %%
data_labels = ["2/23", "2/24", "2/25"]

data_open = [54087.67000000, 48891.00000000, 49676.21000000]
data_close = [48891.00000000, 49676.20000000, 47073.73000000]
data_high = [54183.59000000, 51374.99000000, 52041.73000000]
data_low = [44892.56000000, 46988.69000000, 46674.34000000]


plt.plot(data_labels, data_open, label="Open")
plt.plot(data_labels, data_close, label="Close")
plt.plot(data_labels, data_high, label="High")
plt.plot(data_labels, data_low, label="Low")

plt.grid(color='#95a5a6', linestyle='--', linewidth=1, axis='y', alpha=0.7)

plt.xticks(range(len(data)), data_labels)
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.title(f"BTC - Week of {data_labels[0]}")
plt.legend()

plt.show()
